# %% [markdown]
# ## EJEMPLO DINOSAURIO
#
# Fémur Dinosaurio. Contexto arqueológico

# %%
import numpy as np # Librería para análisis numérico, funciones matemáticas
import pandas as pd # Librería especializada para leer y manipular datos
import matplotlib.pyplot as plt # Librería especializada para visualizaciones
from sklearn.linear_model import LinearRegression # Librería especializada para análisis de datos y machine Learning

# %%
x = np.array([0.7943, 0.7079, 1.000, 1.1220, 1.6982, 1.2023, 1.9953, 2.2387, 2.5119, 2.5119, 3.1623, 3.5481, 4.4668, 5.8884, 6.7608, 15.136, 15.85])
y = np.array([0.0832, 0.0912, 0.1413, 0.1479, 0.2455, 0.2818, 0.7943, 2.5119, 1.4125, 0.8913, 1.9953, 4.2658, 6.3096, 11.2202, 19.95, 141.25, 158.4893])

# %%
plt.figure(figsize= (5,4))
plt.scatter(x,y)
plt.xlabel('Perímetro [cm]')
plt.ylabel('Peso [kg]')
plt.show()

# %% [markdown]
# Usando el mejor modelo para este conjunto de puntos ¿Cuál sería el peso del animal para un diámetro de 10cm?

# %% [markdown]
# ### Regresión lineal

# %%
x = np.array([0.7943, 0.7079, 1.000, 1.1220, 1.6982, 1.2023, 1.9953, 2.2387, 2.5119, 2.5119, 3.1623, 3.5481, 4.4668, 5.8884, 6.7608, 15.136, 15.85]).reshape(-1,1)
y = np.array([0.0832, 0.0912, 0.1413, 0.1479, 0.2455, 0.2818, 0.7943, 2.5119, 1.4125, 0.8913, 1.9953, 4.2658, 6.3096, 11.2202, 19.95, 141.25, 158.4893])

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
m = model.coef_[0]
b =  model.intercept_
r2 = model.score(x, y).round(2)

print(f'm = {m}')
print(f'b = {b}')
print(f'r2 = {r2}')
# Out:
# m = 10.196818618639847
# b = -21.75072298241283
# r2 = 0.92

# %%
plt.figure(figsize= (4,3))
plt.scatter(x, y, color='red', label='Datos originales')
plt.plot(x, m*x + b, label= 'Modelo Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ### Ley de potencias

# %%
X = np.log(x)
Y = np.log(y)

# %%
modelp = LinearRegression() # Modelo de ley de potencias
modelp.fit(X, Y)
# Out:
# LinearRegression()

# %%
a = modelp.coef_[0].round(2)
lnk = modelp.intercept_
k = np.exp(lnk).round(2)
r2p = modelp.score(X, Y).round(2)

print(f'k = {k}')
print(f'a = {a}')
print(f'r2 = {r2p}')
# Out:
# k = 0.14
# a = 2.51
# r2 = 0.98

# %%
plt.figure(figsize= (10,3))
plt.subplot(1, 2, 1)
plt.title('Con logaritmo')
plt.scatter(X, Y)
plt.plot(X, a*X + lnk, color= 'red')
plt.xlabel('ln(x)')
plt.ylabel('ln(y)')

plt.subplot(1, 2, 2)
plt.title('Sin logaritmo')
plt.scatter(x, y)
plt.plot(x, k*(x**a), color= 'red')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
xn = np.sort(np.append(x, 10))
xn
# Out:
# array([ 0.7079,  0.7943,  1.    ,  1.122 ,  1.2023,  1.6982,  1.9953,
#         2.2387,  2.5119,  2.5119,  3.1623,  3.5481,  4.4668,  5.8884,
#         6.7608, 10.    , 15.136 , 15.85  ])

# %%
plt.figure(figsize=(4,3))
plt.scatter(x, y)
plt.plot(xn, k*(xn**a), color= 'red')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# ### Modelo exponencial

# %%
modele = LinearRegression() # Modelo exponencial
modele.fit(x, Y)
# Out:
# LinearRegression()

# %%
n = modele.coef_[0].round(2)
lnc = modele.intercept_
c = np.exp(lnc).round(2)
r2e = modele.score(x, Y).round(2)

print(f'n = {n}')
print(f'c = {c}')
print(f'r2 = {r2e}')
# Out:
# n = 0.47
# c = 0.24
# r2 = 0.82

# %%
plt.figure(figsize= (10,3))
plt.subplot(1, 2, 1)
plt.title('Con logaritmo (y)')
plt.scatter(x, Y)
plt.plot(x, n*x + lnc, color= 'red')
plt.xlabel('x')
plt.ylabel('ln(y)')

plt.subplot(1, 2, 2)
plt.title('Sin logaritmo')
plt.scatter(x, y)
plt.plot(x, c*np.exp(n*x), color= 'red')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
def pesoDinosaurio(d):
    peso = k*(d**a)
    print( f'El peso del dinosaurio es: {peso.round(3)} kg')

# %%
pesoDinosaurio(10)
# Out:
# El peso del dinosaurio es: 45.303 kg
