# %% [markdown]
# ## REGRESIÓN LINEAL
#
# Clase 18/07/2023

# %%
import numpy as np # Librería para análisis numérico, funciones matemáticas
import pandas as pd # Librería especializada para leer y manipular datos
import matplotlib.pyplot as plt # Librería especializada para visualizaciones
from sklearn.linear_model import LinearRegression # Librería especializada para análisis de datos y machine Learning

# %% [markdown]
# Datos

# %%
x = np.array([5, 15, 25, 35, 45, 55 ]).reshape(-1, 1)
y = np.array([5, 20, 14, 32, 22, 38 ])

plt.figure(figsize= (4,3))
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
print(x)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]

# %% [markdown]
# ### Ajuste Lineal

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
np.array([5, 15, 25, 35, 45, 55 ]).reshape(-1, 1) # reshape (filas (-1 lo entiende como el total de filas), columnas)
# Out:
# array([[ 5],
#        [15],
#        [25],
#        [35],
#        [45],
#        [55]])

# %% [markdown]
# Predecir valores de 'y' según el modelo lineal

# %%
model.predict(x)
# Out:
# array([ 8.33333333, 13.73333333, 19.13333333, 24.53333333, 29.93333333,
#        35.33333333])

# %%
plt.figure(figsize= (4,3))
plt.scatter(x, y, color='red', label='Datos originales')
plt.plot(x, model.predict(x), label= 'Modelo Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# La ecuación de la recta es:
#
# $$ y = mx + b $$

# %%
m = model.coef_[0]
m
# Out:
# 0.54

# %%
b =  model.intercept_
b
# Out:
# 5.633333333333329

# %%
print(f'm = {m}')
print(f'b = {b.round(2)}')
print(f'Ecuación de la recta: {m}x + {b.round(2)}')
# Out:
# m = 0.54
# b = 5.63
# Ecuación de la recta: 0.54x + 5.63

# %%
plt.figure(figsize= (5,4))
plt.scatter(x, y, color='red', label='Datos originales')
plt.plot(x, model.predict(x), label= 'Modelo Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.text(5, 28, f'Ecuación de la recta:\n y = {m}x + {b.round(2)}' )
plt.legend()
plt.show()

# %% [markdown]
# ### Correlación Lineal
#
# Coeficiente de correlación r2

# %%
r2 = model.score(x, y).round(2)
r2
# Out:
# 0.72

# %%
print(f'm = {m}')
print(f'b = {b.round(2)}')
print(f'r2 = {r2.round(2)}')
print(f'Ecuación de la recta: {m}x + {b.round(2)}')
# Out:
# m = 0.54
# b = 5.63
# r2 = 0.72
# Ecuación de la recta: 0.54x + 5.63

# %%
plt.figure(figsize= (5,4))
plt.scatter(x, y, color='red', label='Datos originales')
plt.plot(x, model.predict(x), label= 'Modelo Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.text(5, 28, f'Ecuación de la recta:\n y = {m}x + {b.round(2)}' )
plt.text(35, 15, f'm = {m}' )
plt.text(35, 13, f'b = {b.round(2)}' )
plt.text(35, 11, f'r2 = {r2.round(2)}' )
plt.legend()
plt.show()
