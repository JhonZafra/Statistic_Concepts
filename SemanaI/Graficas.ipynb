# %% [markdown]
# # GRÁFICAS
#
# **Librerías** : Conjunto de programas específicos para realizar una tarea, las más comunes para visualización son matplotlib y seaborn

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4, 5], [3, 5, 8, 9, 2], 'bo') # bo = blueCircle, otras opciones = bo, ro, mo, k*
plt.show() # Muestra la gráfica

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [3, 5, 8, 9, 2, 0, 2, 4]
plt.xlabel('Eje Horizontal')
plt.ylabel('Eje vertical')
plt.title('Gráfico primera clase')
plt.plot(x, y, '--', linewidth=2) # Linestyle
plt.grid()

# %%
plt.scatter(x, y)
plt.ylabel('Eje vertical')
plt.title('Gráfico primera clase')
plt.grid()

# %%
grupos = ['Grupo a', 'Grupo b', 'Grupo c', 'Grupo d',]
valores = [3, 5, 7, 2]

plt.bar(grupos, valores)
plt.show()

# %% [markdown]
# ### NUMPY (*NUMERICAL PYTHON*)

# %%
import numpy as np

# %%
t = np.arange(0, 5, 0.1)

# %%
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g')
plt.show()

# %%
x = np.random.rand(100) # Genera números aleatorios entre 0 y 1
plt.plot(x)
plt.show()

# %%
plt.hist(x) # Graficar un hinstograma
plt.show()
