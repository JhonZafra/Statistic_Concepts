# %% [markdown]
# ## Clasificación con la librería Iris

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = datasets.load_iris()

# %%
X = data.data # Cargo solo los valores

# %%
y = data.target

# %%
plt.figure (figsize= (4,3))
plt.scatter(X[:, 0], X[:,1], c = y)
plt.show()

# %% [markdown]
# Calcular el número de clusters

# %%
inercias = []

for n in range(1, 11):
    kmeans = KMeans(n_clusters = n, n_init = 10)
    kmeans.fit(X)
    inercias.append(round(kmeans.inertia_,2))

print(inercias)
# Out:
# [681.37, 152.35, 78.85, 57.26, 46.45, 39.04, 34.48, 30.11, 27.89, 25.96]

# %%
plt.figure( figsize= (4,3) )
plt.title('Gráfica de codo')
plt.plot(range(1, 11), inercias, '-o')
plt.xlabel('Número de clústers')
plt.ylabel('Inercia')
plt.xticks(range(1,11))
plt.show()
